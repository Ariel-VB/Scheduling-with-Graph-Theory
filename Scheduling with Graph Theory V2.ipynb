# %% [markdown]
# <img src="Callysto_Notebook-Banner_Top_06.06.18.jpg"/>

# %% [markdown]
# ## Exam Scheduling with Graph Theory

# %%
#Running this cell displays a button to toggle hidden code
#From: http://chris-said.io/2016/02/13/how-to-make-polished-jupyter-presentations-with-optional-code-visibility/

from IPython.display import HTML

HTML('''<script>
  function code_toggle() {
    if (code_shown){
      $('div.input').hide('500');
      $('#toggleButton').val('Show Code')
    } else {
      $('div.input').show('500');
      $('#toggleButton').val('Hide Code')
    }
    code_shown = !code_shown
  }
  
  $( document ).ready(function(){
    code_shown=false;
    $('div.input').hide()
  });
</script>
<form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>''')
# Out:
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %% [markdown]
# This notebook takes data containing student ID numbers and what classes they take in order to create an optimal (minimum number of days) exam schedule with no conflicts. The conditions for this schedule are:
#
# * There are two sessions for exams on each day - AM and PM.
# * No student will write two exams on the same day.
# * The exam space is limited to 150 students at any time.
#
# This notebook works with data where column 1 contains the grade of the student, column 2 contains student numbers, and column 3 contains class names.
#
# ### Exam Scheduling Code

# %%
'''
Setting up the tools we'll be using in this notebook:
'''

import networkx as nx
import grinpy as gp
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display, HTML
from collections import OrderedDict

from OptimalGraphColoring import optimal_colorings

# %matplotlib inline

# %%
'''
Reading the data into the notebook:
'''

#Opening excel file of data:
data = pd.read_excel('Input Data.xlsx', header = None)

#Putting the data into a pandas dataframe:
data_df = pd.DataFrame(data)
data_df.columns =['Grade','Student ID','Class']

#Displaying the data:
display(HTML(data_df.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Grade</th>
#       <th>Student ID</th>
#       <th>Class</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>12</td>
#       <td>603</td>
#       <td>Calculus12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>603</td>
#       <td>Law12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>630</td>
#       <td>Calculus12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>630</td>
#       <td>History12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>630</td>
#       <td>Law12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>685</td>
#       <td>Calculus12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>685</td>
#       <td>Chemistry12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>797</td>
#       <td>BiologyAnatomyPhysiology12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>890</td>
#       <td>BiologyAnatomyPhysiology12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>890</td>
#       <td>History12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>890</td>
#       <td>Law12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>902</td>
#       <td>FoundationsofMathematics12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>902</td>
#       <td>Geology12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>902</td>
#       <td>Law12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>924</td>
#       <td>History12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>924</td>
#       <td>Law12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>933</td>
#       <td>FoundationsofMathematics12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>933</td>
#       <td>History12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>943</td>
#       <td>History12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>943</td>
#       <td>Law12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>951</td>
#       <td>Calculus12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>951</td>
#       <td>Geology12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>951</td>
#       <td>Law12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1010</td>
#       <td>History12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1021</td>
#       <td>Calculus12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1021</td>
#       <td>PreCalculus12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1026</td>
#       <td>Calculus12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1026</td>
#       <td>Chemistry12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1026</td>
#       <td>Law12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1026</td>
#       <td>Physics12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1042</td>
#       <td>Calculus12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1047</td>
#       <td>BiologyAnatomyPhysiology12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1047</td>
#       <td>Calculus12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1047</td>
#       <td>Chemistry12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1051</td>
#       <td>Calculus12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1051</td>
#       <td>History12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1051</td>
#       <td>PreCalculus12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1052</td>
#       <td>Calculus12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1052</td>
#       <td>Geology12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1052</td>
#       <td>Law12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1053</td>
#       <td>FoundationsofMathematics12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1053</td>
#       <td>Law12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1057</td>
#       <td>BiologyAnatomyPhysiology12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1058</td>
#       <td>FoundationsofMathematics12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1058</td>
#       <td>History12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1058</td>
#       <td>Law12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1062</td>
#       <td>Geology12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1062</td>
#       <td>Law12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1067</td>
#       <td>Geology12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1067</td>
#       <td>History12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1067</td>
#       <td>Law12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1067</td>
#       <td>PreCalculus12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1069</td>
#       <td>Law12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1069</td>
#       <td>Physics12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1069</td>
#       <td>PreCalculus12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1073</td>
#       <td>Calculus12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1073</td>
#       <td>Law12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1074</td>
#       <td>FoundationsofMathematics12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1074</td>
#       <td>Geology12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1074</td>
#       <td>History12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1074</td>
#       <td>Law12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1079</td>
#       <td>FoundationsofMathematics12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1079</td>
#       <td>Geology12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1079</td>
#       <td>Law12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1081</td>
#       <td>BiologyAnatomyPhysiology12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1081</td>
#       <td>Calculus12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1081</td>
#       <td>Law12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1081</td>
#       <td>Physics12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1082</td>
#       <td>Calculus12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1082</td>
#       <td>Law12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1087</td>
#       <td>Calculus12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1087</td>
#       <td>Chemistry12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1087</td>
#       <td>PreCalculus12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1097</td>
#       <td>Calculus12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1097</td>
#       <td>Chemistry12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1097</td>
#       <td>History12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1097</td>
#       <td>Law12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1102</td>
#       <td>BiologyAnatomyPhysiology12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1102</td>
#       <td>FoundationsofMathematics12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1102</td>
#       <td>Law12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1111</td>
#       <td>Calculus12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1111</td>
#       <td>Geology12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1111</td>
#       <td>Law12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1125</td>
#       <td>FoundationsofMathematics12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1125</td>
#       <td>History12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1125</td>
#       <td>Law12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1126</td>
#       <td>FoundationsofMathematics12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1126</td>
#       <td>History12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1140</td>
#       <td>History12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1140</td>
#       <td>Law12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1140</td>
#       <td>PreCalculus12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1147</td>
#       <td>BiologyAnatomyPhysiology12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1147</td>
#       <td>Law12</td>

# %%
'''
Creating a dictionary that lists each student and their classes:
'''

#Getting the list of unique students:
students = data.iloc[:, 1].tolist()
students = set(students)

#Creating a dictionary that will be in the form: {student1 : [class1, class2], student2 : [class2, class4] ...}
student_dictionary = {}

#Iterates through each row in the data:
for row in data.itertuples():
    
    #If this row is a student not yet added to the dictionary:
    if row[2] not in student_dictionary:
        
        #Add this student and the class for this row
        student_dictionary[row[2]] = [row[3]]
            
    #If the student already has a dictionary entry:
    else:
        
        #Add the class to the value list:
        student_dictionary[row[2]].append(row[3])
        
#Converting student_dictionary to a pandas dataframe:
student_data = pd.DataFrame([(k, v) for k, v in student_dictionary.items()])
student_data.columns =['Student ID','Classes']

#Displaying the dataframe:
display(HTML(student_data.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Student ID</th>
#       <th>Classes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>603</td>
#       <td>[Calculus12, Law12]</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>[Calculus12, History12, Law12]</td>
#     </tr>
#     <tr>
#       <td>685</td>
#       <td>[Calculus12, Chemistry12]</td>
#     </tr>
#     <tr>
#       <td>797</td>
#       <td>[BiologyAnatomyPhysiology12]</td>
#     </tr>
#     <tr>
#       <td>890</td>
#       <td>[BiologyAnatomyPhysiology12, History12, Law12]</td>
#     </tr>
#     <tr>
#       <td>902</td>
#       <td>[FoundationsofMathematics12, Geology12, Law12]</td>
#     </tr>
#     <tr>
#       <td>924</td>
#       <td>[History12, Law12]</td>
#     </tr>
#     <tr>
#       <td>933</td>
#       <td>[FoundationsofMathematics12, History12]</td>
#     </tr>
#     <tr>
#       <td>943</td>
#       <td>[History12, Law12]</td>
#     </tr>
#     <tr>
#       <td>951</td>
#       <td>[Calculus12, Geology12, Law12]</td>
#     </tr>
#     <tr>
#       <td>1010</td>
#       <td>[History12]</td>
#     </tr>
#     <tr>
#       <td>1021</td>
#       <td>[Calculus12, PreCalculus12]</td>
#     </tr>
#     <tr>
#       <td>1026</td>
#       <td>[Calculus12, Chemistry12, Law12, Physics12]</td>
#     </tr>
#     <tr>
#       <td>1042</td>
#       <td>[Calculus12]</td>
#     </tr>
#     <tr>
#       <td>1047</td>
#       <td>[BiologyAnatomyPhysiology12, Calculus12, Chemi...</td>
#     </tr>
#     <tr>
#       <td>1051</td>
#       <td>[Calculus12, History12, PreCalculus12]</td>
#     </tr>
#     <tr>
#       <td>1052</td>
#       <td>[Calculus12, Geology12, Law12]</td>
#     </tr>
#     <tr>
#       <td>1053</td>
#       <td>[FoundationsofMathematics12, Law12]</td>
#     </tr>
#     <tr>
#       <td>1057</td>
#       <td>[BiologyAnatomyPhysiology12]</td>
#     </tr>
#     <tr>
#       <td>1058</td>
#       <td>[FoundationsofMathematics12, History12, Law12]</td>
#     </tr>
#     <tr>
#       <td>1062</td>
#       <td>[Geology12, Law12]</td>
#     </tr>
#     <tr>
#       <td>1067</td>
#       <td>[Geology12, History12, Law12, PreCalculus12]</td>
#     </tr>
#     <tr>
#       <td>1069</td>
#       <td>[Law12, Physics12, PreCalculus12]</td>
#     </tr>
#     <tr>
#       <td>1073</td>
#       <td>[Calculus12, Law12]</td>
#     </tr>
#     <tr>
#       <td>1074</td>
#       <td>[FoundationsofMathematics12, Geology12, Histor...</td>
#     </tr>
#     <tr>
#       <td>1079</td>
#       <td>[FoundationsofMathematics12, Geology12, Law12]</td>
#     </tr>
#     <tr>
#       <td>1081</td>
#       <td>[BiologyAnatomyPhysiology12, Calculus12, Law12...</td>
#     </tr>
#     <tr>
#       <td>1082</td>
#       <td>[Calculus12, Law12]</td>
#     </tr>
#     <tr>
#       <td>1087</td>
#       <td>[Calculus12, Chemistry12, PreCalculus12]</td>
#     </tr>
#     <tr>
#       <td>1097</td>
#       <td>[Calculus12, Chemistry12, History12, Law12]</td>
#     </tr>
#     <tr>
#       <td>1102</td>
#       <td>[BiologyAnatomyPhysiology12, FoundationsofMath...</td>
#     </tr>
#     <tr>
#       <td>1111</td>
#       <td>[Calculus12, Geology12, Law12]</td>
#     </tr>
#     <tr>
#       <td>1125</td>
#       <td>[FoundationsofMathematics12, History12, Law12]</td>
#     </tr>
#     <tr>
#       <td>1126</td>
#       <td>[FoundationsofMathematics12, History12]</td>
#     </tr>
#     <tr>
#       <td>1140</td>
#       <td>[History12, Law12, PreCalculus12]</td>
#     </tr>
#     <tr>
#       <td>1147</td>
#       <td>[BiologyAnatomyPhysiology12, Law12, Physics12,...</td>
#     </tr>
#     <tr>
#       <td>1148</td>
#       <td>[BiologyAnatomyPhysiology12, Calculus12, Law12]</td>
#     </tr>
#     <tr>
#       <td>1161</td>
#       <td>[Calculus12, Chemistry12]</td>
#     </tr>
#     <tr>
#       <td>1162</td>
#       <td>[FoundationsofMathematics12, Geology12, Histor...</td>
#     </tr>
#     <tr>
#       <td>1272</td>
#       <td>[BiologyAnatomyPhysiology12, Calculus12, Chemi...</td>
#     </tr>
#     <tr>
#       <td>1282</td>
#       <td>[BiologyLifeSciences11Enriched, PreCalculus11]</td>
#     </tr>
#     <tr>
#       <td>1292</td>
#       <td>[PreCalculus12, SocialStudies11]</td>
#     </tr>
#     <tr>
#       <td>1294</td>
#       <td>[BiologyAnatomyPhysiology12, Chemistry12, Phys...</td>
#     </tr>
#     <tr>
#       <td>1310</td>
#       <td>[Calculus12, Chemistry12, Physics12, SocialStu...</td>
#     </tr>
#     <tr>
#       <td>1334</td>
#       <td>[Chemistry11, Physics11, PreCalculus12, Social...</td>
#     </tr>
#     <tr>
#       <td>1342</td>
#       <td>[Chemistry11, Physics11, PreCalculus11, Social...</td>
#     </tr>
#     <tr>
#       <td>1348</td>
#       <td>[Calculus12, History12, Law12]</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>[BiologyAnatomyPhysiology12, FoundationsofMath...</td>
#     </tr>
#     <tr>
#       <td>1358</td>
#       <td>[BiologyLifeSciences11, FoundationsofMathemati...</td>
#     </tr>
#     <tr>
#       <td>1359</td>
#       <td>[BiologyLifeSciences11Enriched, Chemistry12]</td>
#     </tr>
#     <tr>
#       <td>1360</td>
#       <td>[Chemistry11, Physics11, PreCalculus12]</td>
#     </tr>
#     <tr>
#       <td>1362</td>
#       <td>[BiologyLifeSciences11, PreCalculus12]</td>
#     </tr>
#     <tr>
#       <td>1364</td>
#       <td>[FoundationsofMathematics11, History12]</td>
#     </tr>
#     <tr>
#       <td>1365</td>
#       <td>[Chemistry11, History12, Physics11, PreCalculu...</td>
#     </tr>
#     <tr>
#       <td>1366</td>
#       <td>[Chemistry11Enriched, Physics11, PreCalculus12...</td>
#     </tr>
#     <tr>
#       <td>1370</td>
#       <td>[BiologyAnatomyPhysiology12, Chemistry11Enrich...</td>
#     </tr>
#     <tr>
#       <td>1376</td>
#       <td>[Chemistry11Enriched, Physics11, PreCalculus12]</td>
#     </tr>
#     <tr>
#       <td>1377</td>
#       <td>[Chemistry11Enriched, Physics11, PreCalculus11]</td>
#     </tr>
#     <tr>
#       <td>1378</td>
#       <td>[BiologyLifeSciences11, FoundationsofMathemati...</td>
#     </tr>
#     <tr>
#       <td>1379</td>
#       <td>[Physics11, PreCalculus11, SocialStudies11]</td>
#     </tr>
#     <tr>
#       <td>1382</td>
#       <td>[Chemistry11Enriched, History12, PreCalculus11]</td>
#     </tr>
#     <tr>
#       <td>1383</td>
#       <td>[BiologyAnatomyPhysiology12, Chemistry12, Phys...</td>
#     </tr>
#     <tr>
#       <td>1388</td>
#       <td>[Chemistry11, Physics11, PreCalculus11]</td>
#     </tr>
#     <tr>
#       <td>1390</td>
#       <td>[BiologyLifeSciences11, Chemistry11, Foundatio...</td>
#     </tr>
#     <tr>
#       <td>1392</td>
#       <td>[History12, Physics11, PreCalculus12]</td>
#     </tr>
#     <tr>
#       <td>1412</td>
#       <td>[Physics11, PreCalculus11, SocialStudies11]</td>
#     </tr>
#     <tr>
#       <td>1425</td>
#       <td>[Chemistry11Enriched, History12, Physics11, Pr...</td>
#     </tr>
#     <tr>
#       <td>1426</td>
#       <td>[BiologyAnatomyPhysiology12, Chemistry12, Phys...</td>
#     </tr>
#     <tr>
#       <td>1434</td>
#       <td>[BiologyLifeSciences11, FoundationsofMathemati...</td>
#     </tr>
#     <tr>
#       <td>1444</td>
#       <td>[BiologyAnatomyPhysiology12, Calculus12, Chemi...</td>
#     </tr>
#     <tr>
#       <td>1447</td>
#       <td>[Calculus12, Chemistry11Enriched]</td>
#     </tr>
#     <tr>
#       <td>1448</td>
#       <td>[Chemistry11Enriched]</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>[Chemistry11Enriched, PreCalculus11]</td>
#     </tr>
#     <tr>
#       <td>1455</td>
#       <td>[Chemistry12, Physics12, PreCalculus12Accelera...</td>
#     </tr>
#     <tr>
#       <td>1465</td>
#       <td>[BiologyLifeSciences11, Chemistry11Enriched, P...</td>
#     </tr>
#     <tr>
#       <td>1468</td>
#       <td>[Calculus12, History12]</td>
#     </tr>
#     <tr>
#       <td>1475</td>
#       <td>[BiologyLifeSciences11, Physics11, PreCalculus...</td>
#     </tr>
#     <tr>
#       <td>1508</td>
#       <td>[Calculus12, Chemistry12, Physics12]</td>
#     </tr>
#     <tr>
#       <td>1534</td>
#       <td>[FoundationsofMathematics11]</td>
#     </tr>
#     <tr>
#       <td>1564</td>
#       <td>[FoundationsofMathPreCalc.10, Science10]</td>
#     </tr>
#     <tr>
#       <td>1565</td>
#       <td>[PreCalculus11, Science10]</td>
#     </tr>
#     <tr>
#       <td>1566</td>
#       <td>[FoundationsofMathPreCalc.10, Science10]</td>
#     </tr>
#     <tr>
#       <td>1567</td>
#       <td>[PreCalculus11Accelerated, Science10]</td>
#     </tr>
#     <tr>
#       <td>1571</td>
#       <td>[English9, Mathematics9, Sc

# %%
'''
Creating a dictionary that lists each class and the number of students in that class:
'''

#Getting the list of unique classes
classes = data.iloc[:, 2].tolist()
classes = set(classes)

#Create a dictionary that will be in the form: {class1: number of students in class1, ...}
class_dictionary = {}

#Iterates through each row in the data:
for row in data.itertuples():
    
    #If this row is a class not yet added to the dictionary:
    if row[3] not in class_dictionary:
        
        #Add one to the number of students in this class:
        class_dictionary[row[3]] = 1
        
    #If the student already has a dictionary entry:
    else:
        
        #Add one to the number of students in this class:
        class_dictionary[row[3]] += 1
        
#Converting class_dictionary to a pandas dataframe:
class_data = pd.DataFrame([(k, v) for k, v in class_dictionary.items()])
class_data.columns =['Class','Number of Students']

#Displaying the dataframe:
display(HTML(class_data.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Class</th>
#       <th>Number of Students</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Calculus12</td>
#       <td>71</td>
#     </tr>
#     <tr>
#       <td>Law12</td>
#       <td>57</td>
#     </tr>
#     <tr>
#       <td>History12</td>
#       <td>48</td>
#     </tr>
#     <tr>
#       <td>Chemistry12</td>
#       <td>52</td>
#     </tr>
#     <tr>
#       <td>BiologyAnatomyPhysiology12</td>
#       <td>43</td>
#     </tr>
#     <tr>
#       <td>FoundationsofMathematics12</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <td>Geology12</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <td>PreCalculus12</td>
#       <td>54</td>
#     </tr>
#     <tr>
#       <td>Physics12</td>
#       <td>34</td>
#     </tr>
#     <tr>
#       <td>BiologyLifeSciences11Enriched</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <td>PreCalculus11</td>
#       <td>69</td>
#     </tr>
#     <tr>
#       <td>SocialStudies11</td>
#       <td>40</td>
#     </tr>
#     <tr>
#       <td>Physics11</td>
#       <td>77</td>
#     </tr>
#     <tr>
#       <td>Chemistry11</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <td>BiologyLifeSciences11</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <td>FoundationsofMathematics11</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <td>Chemistry11Enriched</td>
#       <td>56</td>
#     </tr>
#     <tr>
#       <td>PreCalculus12Accelerated</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <td>FoundationsofMathPreCalc.10</td>
#       <td>109</td>
#     </tr>
#     <tr>
#       <td>Science10</td>
#       <td>63</td>
#     </tr>
#     <tr>
#       <td>PreCalculus11Accelerated</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <td>English9</td>
#       <td>117</td>
#     </tr>
#     <tr>
#       <td>Mathematics9</td>
#       <td>69</td>
#     </tr>
#     <tr>
#       <td>Science9</td>
#       <td>124</td>
#     </tr>
#     <tr>
#       <td>SocialStudies9</td>
#       <td>124</td>
#     </tr>
#     <tr>
#       <td>French9Enriched</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <td>Spanish9</td>
#       <td>58</td>
#     </tr>
#     <tr>
#       <td>French9</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <td>Science10Enriched</td>
#       <td>22</td>
#     </tr>
#   </tbody>
# </table>

# %%
'''
Creating the conflict graph, and counting the number of nodes and edges:
'''

#Creating graph G
G = nx.Graph()

#Adding each unique class as a node in the graph
for item in classes:
    G.add_node(item)
    
#Iterates through the dictionary of students, adding conflict edges between all the classes each student has:
for student in student_dictionary:
    
    #Iterates through all pairs of classes for the student:
    for x in range(0, len(student_dictionary[student])):
        for y in range (x+1, len(student_dictionary[student])):
            
            #Creates edge for conflict:
            G.add_edge(student_dictionary[student][x], student_dictionary[student][y])
            
#Finding number of nodes and edges in the conflict graph
node_count = G.number_of_nodes()
edge_count = G.number_of_edges()

G_data = {'Nodes': [node_count], 'Edges': [edge_count]}

G_df = pd.DataFrame(G_data)

#Displaying the dataframe:
display(HTML(G_df.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Nodes</th>
#       <th>Edges</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>29</td>
#       <td>149</td>
#     </tr>
#   </tbody>
# </table>

# %%
'''
Draws the conflict graph:
'''

#Each node is a class, each edge is a scheduling conflict.
nx.draw_circular(G, with_labels=False, width = .5, node_color=range(29), node_size=800, cmap=plt.cm.Blues)

# %%
'''
Finds optimal colorings of graph G, and displays one of them. Colors are named 0, 1, 2, etc.
'''

#Calculating optimal colorings:
all_colors = optimal_colorings(G)
    
sample_color = all_colors[0]

#Converting the sample colouring to a pandas dataframe:
color_data = pd.DataFrame([(k, v) for k, v in sample_color.items()])
color_data.columns =['Class','Colour']

#Displaying the dataframe:
display(HTML(color_data.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Class</th>
#       <th>Colour</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>FoundationsofMathematics11</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>PreCalculus12Accelerated</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Science10</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>PreCalculus11Accelerated</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Science10Enriched</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>Geology12</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>BiologyLifeSciences11</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>Chemistry11</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>Science9</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>SocialStudies11</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>FoundationsofMathPreCalc.10</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Physics12</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>Physics11</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>Mathematics9</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Chemistry12</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <td>FoundationsofMathematics12</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>BiologyAnatomyPhysiology12</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>English9</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>Chemistry11Enriched</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <td>SocialStudies9</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>French9Enriched</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>PreCalculus12</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Law12</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>Calculus12</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>History12</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <td>Spanish9</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <td>French9</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>PreCalculus11</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>BiologyLifeSciences11Enriched</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>

# %%
'''
Computes and displays the final schedule:
'''

#Finding the chromatic number:
chro_num = gp.chromatic_number(G)

#The final solution will go into these lists:
final_solution_AM = []
final_solution_PM = []

#This variable is for the while loop below. If it is set to True, the loop will run.
#If it is set to False by the time the loop is completed, that means a working solution has been found.
#If it is set to True by the time the loop is completed, a solution was not found, and the loop will run again.
run = True
success = True

#This index will mark which coloring we will look at out of the list of all_colorings.
index = -1

#This loop examines each optimal coloring until all conditions are met and a solution is found:
while run == True:
    
    #Incrementing the index to look at the next coloring:
    index += 1
    
    #Resetting variables:
    final_solution_AM = []
    final_solution_PM = []
    run = False
    
    #Sets the next coloring to be tested:
    color = all_colors[index]

    #Checks that generated coloring has chromatic number of colors, sets loop to run again if it doesn't:
    for key in color:
        if color[key] >= chro_num:
            run = True
    
    #Checks that no single color has more than 300 students total taking an exam, sets loop to run again if failed:
    if run == False:
        
        student_count = []
        
        #Sets up student_count to be the appropriate size:
        for x in range(0, chro_num):
            student_count.append(0)
            
        for key in color:            
            student_count[color[key]] += class_dictionary[key]
            
        for x in student_count:
            if x >= 300:
                run = True
    
    
    #Tries to fill the AM/PM slots so that no more than 150 students are writing at a time:
    if run == False:
        
        #Setting up counts for the number of students in the gym during each time slot:
        student_count_AM = []
        student_count_PM = []
        
        #Setting up lists of classes for the solution (AM and PM slots), as well as the student count lists
        # so that they have one entry for every day.
        #The index will represent the day number (eg. the first set of classes will be for the first day, etc.)
        for x in range(0, chro_num):
            final_solution_AM.append([])
            final_solution_PM.append([])
            student_count_AM.append(0)
            student_count_PM.append(0)
        
        #Iterates through all the classes on a given day (or a given color),
        # in order to sort them into the AM and PM sessions:
        for x in range(0, chro_num): 
            for key in color:
                if color[key] == x:
                    
                    #Adds the class to the solution in the AM slot, if there is still room for it (less than 150 students):
                    if student_count_AM[x] + class_dictionary[key] <= 150:
                        
                        student_count_AM[x] += class_dictionary[key]
                        final_solution_AM[x].append(key)
                    
                    #If the AM session is full, the class is added to the PM slot:
                    else:
                        student_count_PM[x] += class_dictionary[key]
                        final_solution_PM[x].append(key)
            
            #If the PM session now has more than 150 students, this solution doesn't work, and the loop resets to try again:
            if student_count_PM[x] > 150:
                run = True
     
    #Just in case no solutions were found:
    if index >= (len(all_colors) - 1):
        run = False
        success = False
        print("No solutions were found this time. Please restart the notebook to try again.")
            
            
#The rest of the code puts the schedule into a pandas dataframe, and applies some formatting:  
if success == True:
    
    day_col = []
    session_col = []
    class_col = []
    students_col = []

    for day in range(0, chro_num):

        for class_ in final_solution_AM[day]:
            day_col.append("Day " + str(day+1) + ": " + str(student_count_AM[day]) + " / " + str(student_count_PM[day]) + " students")
            session_col.append("AM")
            class_col.append(class_)
            students_col.append(class_dictionary[class_])

        for class_ in final_solution_PM[day]:
            day_col.append("Day " + str(day+1) + ": " + str(student_count_AM[day]) + " / " + str(student_count_PM[day]) + " students")
            session_col.append("PM")
            class_col.append(class_)
            students_col.append(class_dictionary[class_])

    d = {
        'Day': day_col,
        'Session': session_col,
        'Class': class_col,     
        'Students': students_col}

    df = pd.DataFrame(d,columns=['Day','Session','Class','Students'])
    df1=df.set_index(['Day', 'Session'])

    display(df1)
# Out:
#                                                            Class  Students
# Day                       Session
# Day 1: 123 / 109 students AM          FoundationsofMathematics11        12
#                           AM            PreCalculus12Accelerated        18
#                           AM            PreCalculus11Accelerated        21
#                           AM          FoundationsofMathematics12        18
#                           AM                       PreCalculus12        54
#                           PM         FoundationsofMathPreCalc.10       109
# Day 2: 142 / 124 students AM                           Science10        63
#                           AM               BiologyLifeSciences11        24
#                           AM          BiologyAnatomyPhysiology12        43
#                           AM       BiologyLifeSciences11Enriched        12
#                           PM                            Science9       124
# Day 3: 147 / 117 students AM                   Science10Enriched        22
#                           AM                           Geology12        14
#                           AM                           Physics12        34
#                           AM                           Physics11        77
#                           PM                            English9       117
# Day 4: 97 / 124 students  AM                     SocialStudies11        40
#                           AM                               Law12        57
#                           PM                      SocialStudies9       124
# Day 5: 140 / 69 students  AM                        Mathematics9        69
#                           AM                          Calculus12        71
#                           PM                       PreCalculus11        69
# Day 6: 133 / 58 students  AM                         Chemistry11        25
#                           AM                         Chemistry12        52
#                           AM                 Chemistry11Enriched        56
#                           PM                            Spanish9        58
# Day 7: 100 / 0 students   AM                     French9Enriched        17
#                           AM                           History12        48
#                           AM                             French9        35

# %%
'''
Computes optimal colorings and times the process:
'''

#Starts the timer:
import time
start = time.time()

#Computes optimal colorings:
colorings = optimal_colorings(G)

#Ends the timer and displays results:
end = time.time()
print("Elapsed time: " + str(end - start))
print("Found " + str(len(colorings)) + " optimal colorings.")
print()
print("Sample coloring:")
colorings[0]
# Out:
# Elapsed time: 0.24084734916687012
# Found 4545 optimal colorings.
#
# Sample coloring:
# OrderedDict([('FoundationsofMathematics11', 0),
#              ('PreCalculus12Accelerated', 0),
#              ('Science10', 1),
#              ('PreCalculus11Accelerated', 0),
#              ('Science10Enriched', 1),
#              ('Geology12', 2),
#              ('BiologyLifeSciences11', 1),
#              ('Chemistry11', 4),
#              ('Science9', 1),
#              ('SocialStudies11', 3),
#              ('FoundationsofMathPreCalc.10', 0),
#              ('Physics12', 2),
#              ('Physics11', 2),
#              ('Mathematics9', 0),
#              ('Chemistry12', 5),
#              ('FoundationsofMathematics12', 0),
#              ('BiologyAnatomyPhysiology12', 1),
#              ('English9', 2),
#              ('Chemistry11Enriched', 5),
#              ('SocialStudies9', 3),
#              ('French9Enriched', 4),
#              ('PreCalculus12', 0),
#              ('Law12', 3),
#              ('Calculus12', 4),
#              ('History12', 6),
#              ('Spanish9', 5),
#              ('French9', 4),
#              ('PreCalculus11', 0),
#              ('BiologyLifeSciences11Enriched', 1)])

# %% [markdown]
# <img src="Callysto_Notebook-Banners_Bottom_06.06.18.jpg"/>
